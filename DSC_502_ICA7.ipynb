# %% [markdown]
# <a href="https://colab.research.google.com/github/Lstemm/DSC-502/blob/main/DSC_502_ICA7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
filename = '/content/drive/MyDrive/DATA/boxoffice.csv'
import pandas as pd
boxoffice = pd.read_csv(filename)
boxoffice.head()
# Out:
#    rank                           title       title_short    amount  \
# 0     1        Star Wars: The Last Jedi         Star Wars  71565498
# 1     2  Jumanji: Welcome to the Jungle           Jumanji  36169328
# 2     3                 Pitch Perfect 3   Pitch Perfect 3  19928525
# 3     4            The Greatest Showman  Greatest Showman   8805843
# 4     5                       Ferdinand         Ferdinand   7316746
#
#   amount_text
# 0        $71
# 1        $36
# 2        $19
# 3         $8
# 4         $7

# %%
boxoffice.iloc[0]
# Out:
# rank                                  1
# title          Star Wars: The Last Jedi
# title_short                   Star Wars
# amount                         71565498
# amount_text                        $71
# Name: 0, dtype: object

# %%
boxoffice['amount'].plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# This line produces a bar graph of the "amount" variable.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# This line imports the "matplotlib.pyplot" library to the code.

# %%
plt.figure(figsize=(15, 3))

# %% [markdown]
# This line sets the automatic figure size to length 1500 and height 300.

# %%
plt.bar(boxoffice['title'],boxoffice['amount'])
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# This line also prints a bar graph of the "amount" variable", but now the x-axis is labeled using the "title" variable.
