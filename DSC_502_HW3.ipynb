# %% [markdown]
# <a href="https://colab.research.google.com/github/Lstemm/DSC-502/blob/main/DSC_502_HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Please see examples we did in class. Questions are just variations of what we did earlier.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Q1**. Please read WorldCupMatches.csv to a data frame to proceed

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import csv
with open("/content/drive/MyDrive/DATA/WorldCupMatches.csv") as f:
    reader = csv.DictReader(f)
    wcm_data = list(reader)

df = pd.DataFrame(wcm_data)
df.head()
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name Home Team Goals Away Team Goals Away Team Name  \
# 0         France               4               1         Mexico
# 1            USA               3               0        Belgium
# 2     Yugoslavia               2               1         Brazil
# 3        Romania               3               1           Peru
# 4      Argentina               1               0         France
#
#   Win conditions Attendance Half-time Home Goals Half-time Away Goals  \
# 0                      4444                    3                    0
# 1                     18346                    2                    0
# 2                     24059                    2                    0
# 3                      2549                    1                    0
# 4                     23409                    0                    0
#
#                   Referee               Assistant 1  \
# 0  LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1       MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2     TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3   WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4     REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
#
#                   Assistant 2 RoundID MatchID Home Team Initials  \
# 0         REGO Gilberto (BRA)     201    1096                FRA
# 1       WARNKEN Alberto (CHI)     201    1090                USA
# 2         BALWAY Thomas (FRA)     201    1093                YUG
# 3    MATEUCCI Francisco (URU)     201    1098                ROU
# 4  RADULESCU Constantin (ROU)     201    1085                ARG
#
#   Away Team Initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA

# %% [markdown]
# **Q2** Using seaborn's displot draw density curves to show the distributions of Home Team Goals for every year.

# %%
df['Home Team Goals'] = pd.to_numeric(df['Home Team Goals'])
df['Away Team Goals'] = pd.to_numeric(df['Away Team Goals'])
df['Year'] = pd.to_numeric(df['Year'])
sns.displot(df, x="Home Team Goals", hue="Year", kind="kde")

# %% [markdown]
# **Q3** Draw violin plots to summarize Home Team Goals distributions for each year by using seaborn. Notice that labels are really cluttered. Then please refer to the earlier notebooks to have labels to appear on only select years which end with 0. You can use ax handle to call ax.set_xticklables(labels) for the labels your prepared.

# %%
labels=[x if x%10==0 else None for x in list(df['Year'].unique())]
ax = sns.violinplot(data=df, x="Year", y="Home Team Goals")
ax.set_xticklabels(labels)
# Out:
# /tmp/ipython-input-1184156660.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels)
# [Text(0, 0, '1930'),
#  Text(1, 0, ''),
#  Text(2, 0, ''),
#  Text(3, 0, '1950'),
#  Text(4, 0, ''),
#  Text(5, 0, ''),
#  Text(6, 0, ''),
#  Text(7, 0, ''),
#  Text(8, 0, '1970'),
#  Text(9, 0, ''),
#  Text(10, 0, ''),
#  Text(11, 0, ''),
#  Text(12, 0, ''),
#  Text(13, 0, '1990'),
#  Text(14, 0, ''),
#  Text(15, 0, ''),
#  Text(16, 0, ''),
#  Text(17, 0, ''),
#  Text(18, 0, '2010'),
#  Text(19, 0, '')]

# %% [markdown]
# **Q4** Please install joypy. Then visualize distributions for Home Team Goals and Away Team Goals' for each year. Once you visualize, please add  plt.style.use('seaborn-white') to see how colors change in your second run. Please also add the legend which you can find from the function prototype.

# %%
# !pip install joypy
# Out:
# Collecting joypy
#   Downloading joypy-0.2.6-py2.py3-none-any.whl.metadata (812 bytes)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.12/dist-packages (from joypy) (2.0.2)
# Requirement already satisfied: scipy>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from joypy) (1.16.3)
# Requirement already satisfied: pandas>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from joypy) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from joypy) (3.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.20.0->joypy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.20.0->joypy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.20.0->joypy) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->joypy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->joypy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->joypy) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->joypy) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->joypy) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->joypy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->joypy) (3.3.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->joypy) (1.17.0)
# Downloading joypy-0.2.6-py2.py3-none-any.whl (8.6 kB)
# Installing collected packages: joypy
# Successfully installed joypy-0.2.6

# %%
import joypy as jp
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-v0_8-white')

df['Home Team Goals'] = pd.to_numeric(df['Home Team Goals'], errors='coerce')
df['Away Team Goals'] = pd.to_numeric(df['Away Team Goals'], errors='coerce')
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')

df_cleaned = df.dropna(subset=['Home Team Goals', 'Away Team Goals', 'Year'])

labels=[x if x%10==0 else None for x in list(df_cleaned['Year'].unique())]

jp.joyplot(df_cleaned, column=['Home Team Goals', 'Away Team Goals'], by='Year', labels=labels, range_style='own', grid="y", linewidth=1, legend=True, figsize=(6,5))

# Simply typing 'Seaborn-white' would not work
# Out:
# (<Figure size 600x500 with 21 Axes>,
#  [<Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >])

# %% [markdown]
# **Q5** Please use groupby function on Home Team Initials to see the sum of Home Team Goals which can be saved to another data frame by adding .reset_index() end the end of your line.
#
# Then use your new data frame to visualize those total Home Team Goals for your top 5 countries with a bar plot (You can use Home Team Initials). You can use use df.sort_values() function on your data frame by tweaking the ascending option.
#
# Notice that your x-axis will be having country initials, and y-axis will show the total number of Home Team Goals.

# %%
df['Home Team Goals'] = pd.to_numeric(df['Home Team Goals'], errors='coerce')
df2 = df.groupby('Home Team Initials')['Home Team Goals'].sum().reset_index()
df2.sort_values(by = 'Home Team Goals', ascending = False, inplace = True)
plt.bar(df2['Home Team Initials'][:5], df2['Home Team Goals'][:5])
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# **Q6** Please extract the rows for your top 4 countries (Home Team Initials') with the help of the previous question's answer. Then use joyplot again to visualize densities for 'Home Team Goals' and	'Away Team Goals' on the horizantal axis. Notice that your y-axis labels will be your country initials (Home Team Initials'). Make sure that your legend is visible and use 'dark_background' by calling plt.style.use again.

# %%
# !pip install joypy
import joypy as jp
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('dark_background')

df['Home Team Goals'] = pd.to_numeric(df['Home Team Goals'], errors='coerce')
df['Away Team Goals'] = pd.to_numeric(df['Away Team Goals'], errors='coerce')

df_total_goals = df.groupby('Home Team Initials')[['Home Team Goals']].sum().reset_index()
df_total_goals.sort_values(by='Home Team Goals', ascending=False, inplace=True)

top_4_initials = df_total_goals['Home Team Initials'].head(4).tolist()

df_filtered_top4_teams = df[df['Home Team Initials'].isin(top_4_initials)].copy()

df_filtered_top4_teams.dropna(subset=['Home Team Goals', 'Away Team Goals'], inplace=True)

jp.joyplot(df_filtered_top4_teams, column=['Home Team Goals', 'Away Team Goals'], by='Home Team Initials', range_style='own', grid="y", linewidth=1, legend=True, figsize=(10,7)) # Increased figsize for better visibility
plt.suptitle('Goal Distributions for Top 4 Home Teams', color='white')
plt.show()

# %% [markdown]
# **Q7** Please install seaborn_qqplot as shown below. Then draw a qqplot to compare probability distributions of Home Team Goals and Away Team Goals. Please comment on your finding. Do you think their distributions agree with each other? Please justify your answer by explaining the figure you obtained.

# %%
# !pip install seaborn_qqplot
# Out:
# Collecting seaborn_qqplot
#   Downloading seaborn_qqplot-0.5.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from seaborn_qqplot) (1.16.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from seaborn_qqplot) (2.2.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from seaborn_qqplot) (0.13.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from seaborn_qqplot) (0.9.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas->seaborn_qqplot) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->seaborn_qqplot) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->seaborn_qqplot) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->seaborn_qqplot) (2025.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.12/dist-packages (from seaborn->seaborn_qqplot) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->seaborn_qqplot) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->seaborn_qqplot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->seaborn_qqplot) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->seaborn_qqplot) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->seaborn_qqplot) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->seaborn_qqplot) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->seaborn_qqplot) (3.3.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->seaborn_qqplot) (1.17.0)
# Downloading seaborn_qqplot-0.5.0-py3-none-any.whl (12 kB)
# Installing collected packages: seaborn_qqplot
# Successfully installed seaborn_qqplot-0.5.0

# %%
from seaborn_qqplot import pplot #seaborn-qqplot is a seaborn extension adding qqplots.
plt.style.use('ggplot') #this is to change the color theme.

df['Home Team Goals'] = pd.to_numeric(df['Home Team Goals'], errors='coerce')
df['Away Team Goals'] = pd.to_numeric(df['Away Team Goals'], errors='coerce')

pplot(data=df, x='Home Team Goals', y='Away Team Goals', kind='qq', display_kws={"identity":True}, height=4, aspect=2)

# %% [markdown]
# The distributions for home team goals and away team goals do not seem to agree with each other, as the plots appear to be far below the theortical distribution.
